# %%
import pandas as pd
import tensorflow as tf
from tensorflow.keras.preprocessing.image import load_img, img_to_array, ImageDataGenerator
import numpy as np
import os
import zipfile
import cv2
import matplotlib.pyplot as plt

# %%
# Ekstrak file ZIP
zip_path = '/content/dataset2.zip'
extract_path = '/content/'

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

print(f'File berhasil diekstrak ke {extract_path}')

# Load model segmentasi
segmentation_model = tf.keras.models.load_model('/content/segmentasi_model_unet_best.h5')
# Out:
# File berhasil diekstrak ke /content/
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
# Folder dataset
image_dir = '/content/dataset2'
segmented_dir = '/content/dataset2_segmented'
os.makedirs(segmented_dir, exist_ok=True)

SEGMENTATION_IMG_HEIGHT, SEGMENTATION_IMG_WIDTH = 256, 256
PREDICTION_IMG_HEIGHT, PREDICTION_IMG_WIDTH = 224, 224

# Data augmentation settings
data_gen = ImageDataGenerator(
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.1,
    zoom_range=0.1,
    fill_mode='nearest'
)

def segment_image(image_path):
    image = cv2.imread(image_path)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    image = cv2.resize(image, (SEGMENTATION_IMG_HEIGHT, SEGMENTATION_IMG_WIDTH)) / 255.0
    image_input = np.expand_dims(image, axis=0)
    pred_mask = segmentation_model.predict(image_input)[0]
    pred_mask = (pred_mask > 0.5).astype(np.uint8)
    return pred_mask[:, :, 0]  # Mask biner

images = []
labels = []

# %%
for filename in os.listdir(image_dir):
    if filename.endswith(".jpg"):
        img_path = os.path.join(image_dir, filename)
        mask = segment_image(img_path)
        segmented_path = os.path.join(segmented_dir, filename)
        cv2.imwrite(segmented_path, mask * 255)

        # Load segmented image
        img_array = img_to_array(load_img(segmented_path, target_size=(PREDICTION_IMG_HEIGHT, PREDICTION_IMG_WIDTH))) / 255.0
        label = int(filename.split('.')[0])

        # Tambahkan gambar asli
        images.append(img_array.astype(np.float32))
        labels.append(label)

        # Augmentasi sebanyak 3 kali
        img_array_expanded = np.expand_dims(img_array, axis=0)
        augmented_images = data_gen.flow(img_array_expanded, batch_size=1)

        for _ in range(2):
            aug_img = next(augmented_images)[0]  # Ambil batch pertama
            images.append(aug_img.astype(np.float32))
            labels.append(label)

X = np.array(images)
y = np.array(labels)

print(f"Total gambar setelah augmentasi: {len(X)}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Total gambar setelah augmentasi: 48

# %%
# Model sederhana
model = tf.keras.Sequential([
    tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(PREDICTION_IMG_HEIGHT, PREDICTION_IMG_WIDTH, 3)),
    tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
    tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
    tf.keras.layers.Conv2D(128, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(1, activation='linear')
])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mae'])

checkpoint = tf.keras.callbacks.ModelCheckpoint(
    'best_model.keras',
    monitor='loss',
    save_best_only=True,
    mode='min',
    verbose=1
)

history = model.fit(
    X, y,
    epochs=300,
    batch_size=32,
    callbacks=[checkpoint]
)
# Out:
# Epoch 1/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 234768.4062 - mae: 436.7378
# Epoch 1: loss improved from inf to 235889.42188, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 7s 2s/step - loss: 235142.0781 - mae: 435.5899
# Epoch 2/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 193782.7500 - mae: 379.8034
# Epoch 2: loss improved from 235889.42188 to 186045.82812, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 6s 3s/step - loss: 191203.7656 - mae: 376.4708
# Epoch 3/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 74008.2344 - mae: 196.6616
# Epoch 3: loss improved from 186045.82812 to 73006.40625, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 9s 2s/step - loss: 73674.2891 - mae: 198.5680
# Epoch 4/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 139567.2188 - mae: 334.9187
# Epoch 4: loss did not improve from 73006.40625
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - loss: 136232.6719 - mae: 331.4330
# Epoch 5/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 51966.4062 - mae: 181.8420
# Epoch 5: loss improved from 73006.40625 to 53682.45703, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - loss: 52538.4219 - mae: 181.0305
# Epoch 6/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 68082.2734 - mae: 175.6947
# Epoch 6: loss did not improve from 53682.45703
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 9s 2s/step - loss: 71856.2188 - mae: 181.3687
# Epoch 7/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 93515.8906 - mae: 211.5984
# Epoch 7: loss did not improve from 53682.45703
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - loss: 91098.1484 - mae: 209.7698
# Epoch 8/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 70909.7266 - mae: 177.1479
# Epoch 8: loss did not improve from 53682.45703
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 9s 2s/step - loss: 70112.9688 - mae: 176.2293
# Epoch 9/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 58283.3594 - mae: 178.8748
# Epoch 9: loss did not improve from 53682.45703
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - loss: 57811.0898 - mae: 180.5014
# Epoch 10/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 55868.5742 - mae: 206.6708
# Epoch 10: loss improved from 53682.45703 to 53339.31250, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 5s 2s/step - loss: 55025.4883 - mae: 204.4137
# Epoch 11/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 60148.3320 - mae: 215.1499
# Epoch 11: loss did not improve from 53339.31250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - loss: 59090.7344 - mae: 213.0274
# Epoch 12/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 46123.8594 - mae: 184.1326
# Epoch 12: loss improved from 53339.31250 to 51904.16797, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step - loss: 48050.6289 - mae: 185.4694
# Epoch 13/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 48693.8594 - mae: 163.4067
# Epoch 13: loss improved from 51904.16797 to 47406.26172, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step - loss: 48264.6602 - mae: 162.8797
# Epoch 14/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 54940.7031 - mae: 165.1628
# Epoch 14: loss did not improve from 47406.26172
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - loss: 53070.9453 - mae: 162.5447
# Epoch 15/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 48254.3750 - mae: 161.3691
# Epoch 15: loss improved from 47406.26172 to 47299.56641, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step - loss: 47936.1055 - mae: 160.1817
# Epoch 16/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 37793.5469 - mae: 153.7737
# Epoch 16: loss improved from 47299.56641 to 43354.51172, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step - loss: 39647.2031 - mae: 156.3812
# Epoch 17/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 46047.3398 - mae: 180.4918
# Epoch 17: loss did not improve from 43354.51172
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - loss: 45510.9609 - mae: 178.7614
# Epoch 18/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 42152.9688 - mae: 173.7417
# Epoch 18: loss did not improve from 43354.51172
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 9s 2s/step - loss: 43072.6484 - mae: 175.8716
# Epoch 19/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 42719.2344 - mae: 172.3476
# Epoch 19: loss improved from 43354.51172 to 41942.28516, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - loss: 42460.2500 - mae: 171.9858
# Epoch 20/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 37486.6875 - mae: 152.6794
# Epoch 20: loss improved from 41942.28516 to 40292.37891, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 5s 2s/step - loss: 38421.9180 - mae: 155.3280
# Epoch 21/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 33590.6133 - mae: 142.2072
# Epoch 21: loss did not improve from 40292.37891
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - loss: 36046.2227 - mae: 146.1385
# Epoch 22/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 42777.1875 - mae: 156.4248
# Epoch 22: loss improved from 40292.37891 to 40126.84766, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 5s 2s/step - loss: 41893.7422 - mae: 155.3289
# Epoch 23/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 40745.2031 - mae: 163.7563
# Epoch 23: loss improved from 40126.84766 to 37842.00000, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 6s 3s/step - loss: 39777.4688 - mae: 160.8573
# Epoch 24/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 34722.5625 - mae: 156.0294
# Epoch 24: loss improved from 37842.00000 to 37552.98828, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 5s 2s/step - loss: 35666.0352 - mae: 157.8754
# Epoch 25/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 36365.3516 - mae: 159.0954
# Epoch 25: loss improved from 37552.98828 to 36867.07422, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 5s 2s/step - loss: 36532.5898 - mae: 159.8353
# Epoch 26/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 32754.2539 - mae: 147.5148
# Epoch 26: loss improved from 36867.07422 to 34670.38672, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - loss: 33392.9648 - mae: 148.8914
# Epoch 27/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 36149.7656 - mae: 153.2931
# Epoch 27: loss improved from 34670.38672 to 33803.78516, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - loss: 35367.7734 - mae: 150.7040
# Epoch 28/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 32429.0078 - mae: 143.9954
# Epoch 28: loss improved from 33803.78516 to 32938.21484, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 5s 2s/step - loss: 32598.7441 - mae: 143.2154
# Epoch 29/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 28581.3203 - mae: 133.7915
# Epoch 29: loss improved from 32938.21484 to 30839.75195, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - loss: 29334.1309 - mae: 135.5806
# Epoch 30/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 28234.3555 - mae: 141.6350
# Epoch 30: loss improved from 30839.75195 to 29758.05273, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 9s 2s/step - loss: 28742.2559 - mae: 142.8937
# Epoch 31/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 27683.1328 - mae: 143.2523
# Epoch 31: loss did not improve from 29758.05273
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 9s 2s/step - loss: 28402.9961 - mae: 144.7056
# Epoch 32/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 28792.3652 - mae: 140.9065
# Epoch 32: loss improved from 29758.05273 to 25770.58594, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 7s 2s/step - loss: 27785.1055 - mae: 137.9644
# Epoch 33/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 28345.1758 - mae: 131.5722
# Epoch 33: loss improved from 25770.58594 to 25089.20117, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 9s 2s/step - loss: 27259.8516 - mae: 128.8050
# Epoch 34/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 24898.5000 - mae: 122.7687
# Epoch 34: loss improved from 25089.20117 to 23781.77930, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step - loss: 24526.2598 - mae: 121.6345
# Epoch 35/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 19685.3438 - mae: 113.0698
# Epoch 35: loss improved from 23781.77930 to 19656.30664, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - loss: 19675.6641 - mae: 113.5427
# Epoch 36/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 18256.2148 - mae: 113.5967
# Epoch 36: loss did not improve from 19656.30664
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - loss: 19146.1738 - mae: 116.9760
# Epoch 37/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 17841.5918 - mae: 111.9091
# Epoch 37: loss improved from 19656.30664 to 18338.98242, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 6s 3s/step - loss: 18007.3887 - mae: 112.4183
# Epoch 38/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 17607.3613 - mae: 99.9130
# Epoch 38: loss improved from 18338.98242 to 17932.41992, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step - loss: 17715.7148 - mae: 100.7003
# Epoch 39/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 13270.2559 - mae: 98.6291
# Epoch 39: loss improved from 17932.41992 to 14271.30957, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - loss: 13603.9404 - mae: 99.9937
# Epoch 40/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 13978.3223 - mae: 102.4524
# Epoch 40: loss improved from 14271.30957 to 14060.97168, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 5s 2s/step - loss: 14005.8721 - mae: 102.5600
# Epoch 41/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 11962.3193 - mae: 89.1104
# Epoch 41: loss improved from 14060.97168 to 11238.38574, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 6s 3s/step - loss: 11721.0078 - mae: 88.0903
# Epoch 42/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 11065.1836 - mae: 85.8789
# Epoch 42: loss improved from 11238.38574 to 10314.19043, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 9s 2s/step - loss: 10814.8525 - mae: 84.6679
# Epoch 43/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 9228.6191 - mae: 78.4827
# Epoch 43: loss improved from 10314.19043 to 9019.53418, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - loss: 9158.9248 - mae: 78.4774
# Epoch 44/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 8286.3594 - mae: 74.8883
# Epoch 44: loss improved from 9019.53418 to 7875.96924, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 5s 2s/step - loss: 8149.5630 - mae: 74.0360
# Epoch 45/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 6520.4043 - mae: 65.5362
# Epoch 45: loss improved from 7875.96924 to 6965.77002, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 6s 3s/step - loss: 6668.8594 - mae: 66.2847
# Epoch 46/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 6557.4365 - mae: 65.0775
# Epoch 46: loss improved from 6965.77002 to 6703.97852, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 9s 2s/step - loss: 6606.2837 - mae: 65.4809
# Epoch 47/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 5436.3223 - mae: 58.1493
# Epoch 47: loss improved from 6703.97852 to 5607.28516, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - loss: 5493.3096 - mae: 58.7600
# Epoch 48/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 5463.6997 - mae: 58.7349
# Epoch 48: loss improved from 5607.28516 to 5178.13135, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 9s 3s/step - loss: 5368.5103 - mae: 58.3568
# Epoch 49/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 4461.0400 - mae: 52.3073
# Epoch 49: loss improved from 5178.13135 to 4776.81201, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - loss: 4566.2974 - mae: 53.0824
# Epoch 50/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 3821.5645 - mae: 48.7113
# Epoch 50: loss improved from 4776.81201 to 3694.89746, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - loss: 3779.3420 - mae: 48.4118
# Epoch 51/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 3431.0630 - mae: 47.0130
# Epoch 51: loss improved from 3694.89746 to 3655.13794, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 9s 2s/step - loss: 3505.7546 - mae: 47.3817
# Epoch 52/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 2909.3975 - mae: 42.2021
# Epoch 52: loss improved from 3655.13794 to 2880.55078, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step - loss: 2899.7820 - mae: 42.1215
# Epoch 53/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 2456.7461 - mae: 39.4798
# Epoch 53: loss improved from 2880.55078 to 2508.51123, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - loss: 2474.0012 - mae: 39.5363
# Epoch 54/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 2584.8667 - mae: 38.8108
# Epoch 54: loss did not improve from 2508.51123
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 8s 2s/step - loss: 2573.5957 - mae: 39.0702
# Epoch 55/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 1619.9531 - mae: 32.0269
# Epoch 55: loss improved from 2508.51123 to 1817.97070, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - loss: 1685.9590 - mae: 32.5567
# Epoch 56/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 2708.4121 - mae: 43.7530
# Epoch 56: loss did not improve from 1817.97070
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step - loss: 2617.2029 - mae: 42.9535
# Epoch 57/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 1579.2512 - mae: 31.4822
# Epoch 57: loss improved from 1817.97070 to 1661.68835, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step - loss: 1606.7303 - mae: 31.7927
# Epoch 58/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 1139.1963 - mae: 28.0300
# Epoch 58: loss improved from 1661.68835 to 1183.12305, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - loss: 1153.8385 - mae: 28.1375
# Epoch 59/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 1448.4666 - mae: 30.8626
# Epoch 59: loss did not improve from 1183.12305
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - loss: 1497.6812 - mae: 31.4349
# Epoch 60/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 1129.9867 - mae: 27.5988
# Epoch 60: loss improved from 1183.12305 to 1158.81396, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - loss: 1139.5958 - mae: 27.7655
# Epoch 61/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 1324.9478 - mae: 31.3215
# Epoch 61: loss did not improve from 1158.81396
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 9s 2s/step - loss: 1281.6129 - mae: 30.7017
# Epoch 62/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 972.8193 - mae: 26.1104
# Epoch 62: loss improved from 1158.81396 to 973.69403, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 5s 2s/step - loss: 973.1108 - mae: 26.1056
# Epoch 63/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 605.7407 - mae: 21.0998
# Epoch 63: loss improved from 973.69403 to 566.69318, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step - loss: 592.7249 - mae: 20.8559
# Epoch 64/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 751.4566 - mae: 22.1753
# Epoch 64: loss did not improve from 566.69318
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 733.0329 - mae: 21.8276
# Epoch 65/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 413.1889 - mae: 16.0430
# Epoch 65: loss improved from 566.69318 to 433.55972, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 7s 3s/step - loss: 419.9792 - mae: 16.3741
# Epoch 66/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 383.4545 - mae: 16.3610
# Epoch 66: loss improved from 433.55972 to 356.03879, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 9s 2s/step - loss: 374.3159 - mae: 16.1340
# Epoch 67/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 429.8491 - mae: 15.8759
# Epoch 67: loss did not improve from 356.03879
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - loss: 421.5681 - mae: 15.7954
# Epoch 68/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 285.2485 - mae: 13.1025
# Epoch 68: loss improved from 356.03879 to 300.28540, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 5s 2s/step - loss: 290.2608 - mae: 13.2402
# Epoch 69/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 252.4481 - mae: 13.0448
# Epoch 69: loss improved from 300.28540 to 247.24931, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 6s 3s/step - loss: 250.7151 - mae: 13.0651
# Epoch 70/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 226.2483 - mae: 12.4294
# Epoch 70: loss improved from 247.24931 to 212.80717, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step - loss: 221.7679 - mae: 12.2117
# Epoch 71/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 140.9187 - mae: 9.3068
# Epoch 71: loss improved from 212.80717 to 144.08719, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - loss: 141.9749 - mae: 9.3341
# Epoch 72/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 147.2015 - mae: 9.2000
# Epoch 72: loss improved from 144.08719 to 127.46540, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 9s 3s/step - loss: 140.6228 - mae: 8.9256
# Epoch 73/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 105.0172 - mae: 8.2472
# Epoch 73: loss improved from 127.46540 to 108.37991, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step - loss: 106.1381 - mae: 8.2847
# Epoch 74/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 72.9948 - mae: 6.5677
# Epoch 74: loss improved from 108.37991 to 75.04919, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - loss: 73.6796 - mae: 6.6559
# Epoch 75/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 64.1687 - mae: 6.4426
# Epoch 75: loss improved from 75.04919 to 71.26223, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - loss: 66.5332 - mae: 6.5421
# Epoch 76/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 54.7517 - mae: 5.8881
# Epoch 76: loss improved from 71.26223 to 58.24723, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 9s 2s/step - loss: 55.9169 - mae: 5.9553
# Epoch 77/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 40.9545 - mae: 4.8719
# Epoch 77: loss improved from 58.24723 to 45.49995, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - loss: 42.4697 - mae: 4.9921
# Epoch 78/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 29.0688 - mae: 4.2826
# Epoch 78: loss improved from 45.49995 to 33.79970, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 5s 2s/step - loss: 30.6458 - mae: 4.3892
# Epoch 79/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 27.2428 - mae: 4.1571
# Epoch 79: loss improved from 33.79970 to 26.95983, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 6s 3s/step - loss: 27.1485 - mae: 4.1594
# Epoch 80/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 34.6959 - mae: 4.9600
# Epoch 80: loss did not improve from 26.95983
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - loss: 35.3745 - mae: 5.0119
# Epoch 81/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 13.3839 - mae: 2.7640
# Epoch 81: loss improved from 26.95983 to 15.59726, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 7s 2s/step - loss: 14.1217 - mae: 2.8116
# Epoch 82/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 29.8082 - mae: 4.3777
# Epoch 82: loss did not improve from 15.59726
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 28.4461 - mae: 4.2662
# Epoch 83/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 23.0690 - mae: 3.9760
# Epoch 83: loss did not improve from 15.59726
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - loss: 23.5554 - mae: 4.0253
# Epoch 84/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 11.3970 - mae: 2.7406
# Epoch 84: loss improved from 15.59726 to 14.40162, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step - loss: 12.3985 - mae: 2.8636
# Epoch 85/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 12.8082 - mae: 2.9310
# Epoch 85: loss improved from 14.40162 to 11.31190, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - loss: 12.3095 - mae: 2.8604
# Epoch 86/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 17.1434 - mae: 3.6219
# Epoch 86: loss did not improve from 11.31190
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 17.0388 - mae: 3.5993
# Epoch 87/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 7.9030 - mae: 2.2004
# Epoch 87: loss improved from 11.31190 to 10.55910, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 6s 3s/step - loss: 8.7884 - mae: 2.3075
# Epoch 88/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 8.2898 - mae: 2.2401
# Epoch 88: loss improved from 10.55910 to 8.09906, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 9s 2s/step - loss: 8.2262 - mae: 2.2346
# Epoch 89/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 10.8879 - mae: 2.7954
# Epoch 89: loss did not improve from 8.09906
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - loss: 10.4484 - mae: 2.7217
# Epoch 90/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 7.0800 - mae: 2.1895
# Epoch 90: loss improved from 8.09906 to 6.89934, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - loss: 7.0198 - mae: 2.1885
# Epoch 91/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 2.5937 - mae: 1.2926
# Epoch 91: loss improved from 6.89934 to 3.04926, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step - loss: 2.7455 - mae: 1.3236
# Epoch 92/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 6.2583 - mae: 2.1138
# Epoch 92: loss did not improve from 3.04926
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - loss: 5.9699 - mae: 2.0484
# Epoch 93/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 2.9257 - mae: 1.4615
# Epoch 93: loss did not improve from 3.04926
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 9s 2s/step - loss: 3.0572 - mae: 1.4889
# Epoch 94/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 1.7928 - mae: 0.9647
# Epoch 94: loss improved from 3.04926 to 2.51768, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - loss: 2.0344 - mae: 1.0397
# Epoch 95/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 1.5907 - mae: 1.0424
# Epoch 95: loss improved from 2.51768 to 1.74564, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - loss: 1.6423 - mae: 1.0545
# Epoch 96/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 2.5447 - mae: 1.3187
# Epoch 96: loss did not improve from 1.74564
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 2.4464 - mae: 1.2903
# Epoch 97/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 2.5078 - mae: 1.3427
# Epoch 97: loss did not improve from 1.74564
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 5s 2s/step - loss: 2.6232 - mae: 1.3739
# Epoch 98/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 1.4304 - mae: 0.9144
# Epoch 98: loss did not improve from 1.74564
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - loss: 1.5951 - mae: 0.9735
# Epoch 99/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 1.2407 - mae: 0.9784
# Epoch 99: loss improved from 1.74564 to 1.21981, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 5s 2s/step - loss: 1.2338 - mae: 0.9707
# Epoch 100/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 2.4973 - mae: 1.4319
# Epoch 100: loss did not improve from 1.21981
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - loss: 2.4127 - mae: 1.3995
# Epoch 101/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 1.3812 - mae: 1.0240
# Epoch 101: loss did not improve from 1.21981
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 9s 2s/step - loss: 1.4760 - mae: 1.0526
# Epoch 102/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.5532 - mae: 0.5896
# Epoch 102: loss improved from 1.21981 to 0.72267, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - loss: 0.6097 - mae: 0.6215
# Epoch 103/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 1.0518 - mae: 0.8673
# Epoch 103: loss did not improve from 0.72267
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step - loss: 1.0058 - mae: 0.8409
# Epoch 104/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 1.1004 - mae: 0.9451
# Epoch 104: loss did not improve from 0.72267
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 1.0584 - mae: 0.9234
# Epoch 105/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 0.5523 - mae: 0.5912
# Epoch 105: loss improved from 0.72267 to 0.67511, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - loss: 0.5932 - mae: 0.6181
# Epoch 106/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.2203 - mae: 0.3717
# Epoch 106: loss improved from 0.67511 to 0.30852, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step - loss: 0.2497 - mae: 0.3929
# Epoch 107/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 0.8955 - mae: 0.8451
# Epoch 107: loss did not improve from 0.30852
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - loss: 0.8473 - mae: 0.8121
# Epoch 108/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 0.6392 - mae: 0.6544
# Epoch 108: loss did not improve from 0.30852
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 9s 2s/step - loss: 0.6246 - mae: 0.6485
# Epoch 109/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.3237 - mae: 0.4693
# Epoch 109: loss did not improve from 0.30852
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 5s 2s/step - loss: 0.3487 - mae: 0.4891
# Epoch 110/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 0.2003 - mae: 0.3435
# Epoch 110: loss improved from 0.30852 to 0.25356, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 11s 3s/step - loss: 0.2180 - mae: 0.3609
# Epoch 111/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.3533 - mae: 0.4989
# Epoch 111: loss did not improve from 0.25356
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 0.3348 - mae: 0.4804
# Epoch 112/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.3560 - mae: 0.5319
# Epoch 112: loss did not improve from 0.25356
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 0.3438 - mae: 0.5170
# Epoch 113/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.1396 - mae: 0.2997
# Epoch 113: loss improved from 0.25356 to 0.18779, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - loss: 0.1557 - mae: 0.3165
# Epoch 114/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 0.0796 - mae: 0.2317
# Epoch 114: loss improved from 0.18779 to 0.10737, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - loss: 0.0889 - mae: 0.2449
# Epoch 115/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.1161 - mae: 0.2851
# Epoch 115: loss improved from 0.10737 to 0.10518, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 9s 2s/step - loss: 0.1125 - mae: 0.2788
# Epoch 116/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 0.2394 - mae: 0.3989
# Epoch 116: loss did not improve from 0.10518
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - loss: 0.2320 - mae: 0.3922
# Epoch 117/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 0.1604 - mae: 0.3349
# Epoch 117: loss did not improve from 0.10518
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 9s 2s/step - loss: 0.1604 - mae: 0.3350
# Epoch 118/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0599 - mae: 0.2092
# Epoch 118: loss improved from 0.10518 to 0.06439, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - loss: 0.0614 - mae: 0.2128
# Epoch 119/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 0.0619 - mae: 0.2110
# Epoch 119: loss improved from 0.06439 to 0.05202, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - loss: 0.0586 - mae: 0.2028
# Epoch 120/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.1100 - mae: 0.2950
# Epoch 120: loss did not improve from 0.05202
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 0.1068 - mae: 0.2884
# Epoch 121/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 0.0757 - mae: 0.2285
# Epoch 121: loss did not improve from 0.05202
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - loss: 0.0818 - mae: 0.2360
# Epoch 122/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0400 - mae: 0.1542
# Epoch 122: loss did not improve from 0.05202
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - loss: 0.0442 - mae: 0.1621
# Epoch 123/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0353 - mae: 0.1570
# Epoch 123: loss improved from 0.05202 to 0.03349, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 5s 2s/step - loss: 0.0347 - mae: 0.1567
# Epoch 124/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 0.0758 - mae: 0.2496
# Epoch 124: loss did not improve from 0.03349
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - loss: 0.0717 - mae: 0.2396
# Epoch 125/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0629 - mae: 0.2260
# Epoch 125: loss did not improve from 0.03349
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 9s 2s/step - loss: 0.0614 - mae: 0.2228
# Epoch 126/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0324 - mae: 0.1352
# Epoch 126: loss did not improve from 0.03349
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - loss: 0.0356 - mae: 0.1427
# Epoch 127/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 0.0207 - mae: 0.1157
# Epoch 127: loss improved from 0.03349 to 0.02554, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 11s 3s/step - loss: 0.0223 - mae: 0.1211
# Epoch 128/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0266 - mae: 0.1443
# Epoch 128: loss improved from 0.02554 to 0.02471, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 9s 2s/step - loss: 0.0260 - mae: 0.1430
# Epoch 129/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0211 - mae: 0.1255
# Epoch 129: loss improved from 0.02471 to 0.01788, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - loss: 0.0200 - mae: 0.1206
# Epoch 130/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 0.0310 - mae: 0.1483
# Epoch 130: loss did not improve from 0.01788
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 9s 2s/step - loss: 0.0294 - mae: 0.1424
# Epoch 131/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0115 - mae: 0.0879
# Epoch 131: loss improved from 0.01788 to 0.01310, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - loss: 0.0120 - mae: 0.0903
# Epoch 132/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 0.0069 - mae: 0.0672
# Epoch 132: loss improved from 0.01310 to 0.00734, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - loss: 0.0071 - mae: 0.0682
# Epoch 133/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0057 - mae: 0.0610
# Epoch 133: loss improved from 0.00734 to 0.00517, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 9s 2s/step - loss: 0.0055 - mae: 0.0597
# Epoch 134/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0067 - mae: 0.0678
# Epoch 134: loss did not improve from 0.00517
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 5s 2s/step - loss: 0.0065 - mae: 0.0671
# Epoch 135/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 0.0065 - mae: 0.0685
# Epoch 135: loss did not improve from 0.00517
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step - loss: 0.0064 - mae: 0.0677
# Epoch 136/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0036 - mae: 0.0472
# Epoch 136: loss improved from 0.00517 to 0.00490, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 5s 2s/step - loss: 0.0040 - mae: 0.0500
# Epoch 137/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 0.0019 - mae: 0.0343
# Epoch 137: loss improved from 0.00490 to 0.00247, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 5s 2s/step - loss: 0.0021 - mae: 0.0364
# Epoch 138/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0032 - mae: 0.0432
# Epoch 138: loss did not improve from 0.00247
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 9s 2s/step - loss: 0.0032 - mae: 0.0435
# Epoch 139/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 0.0037 - mae: 0.0518
# Epoch 139: loss did not improve from 0.00247
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - loss: 0.0036 - mae: 0.0506
# Epoch 140/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0049 - mae: 0.0599
# Epoch 140: loss did not improve from 0.00247
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 0.0051 - mae: 0.0612
# Epoch 141/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 0.0049 - mae: 0.0626
# Epoch 141: loss did not improve from 0.00247
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 5s 2s/step - loss: 0.0052 - mae: 0.0644
# Epoch 142/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0019 - mae: 0.0337
# Epoch 142: loss did not improve from 0.00247
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - loss: 0.0023 - mae: 0.0370
# Epoch 143/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - loss: 0.0028 - mae: 0.0456
# Epoch 143: loss did not improve from 0.00247
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 5s/step - loss: 0.0029 - mae: 0.0459
# Epoch 144/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0067 - mae: 0.0709
# Epoch 144: loss did not improve from 0.00247
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - loss: 0.0063 - mae: 0.0681
# Epoch 145/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0059 - mae: 0.0709
# Epoch 145: loss did not improve from 0.00247
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 0.0055 - mae: 0.0681
# Epoch 146/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 0.0024 - mae: 0.0435
# Epoch 146: loss did not improve from 0.00247
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - loss: 0.0025 - mae: 0.0444
# Epoch 147/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 0.0017 - mae: 0.0332
# Epoch 147: loss improved from 0.00247 to 0.00213, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step - loss: 0.0018 - mae: 0.0348
# Epoch 148/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 0.0011 - mae: 0.0272
# Epoch 148: loss improved from 0.00213 to 0.00133, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - loss: 0.0012 - mae: 0.0281
# Epoch 149/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 0.0023 - mae: 0.0438
# Epoch 149: loss did not improve from 0.00133
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 9s 2s/step - loss: 0.0023 - mae: 0.0432
# Epoch 150/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0018 - mae: 0.0369
# Epoch 150: loss did not improve from 0.00133
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 5s 2s/step - loss: 0.0018 - mae: 0.0367
# Epoch 151/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0031 - mae: 0.0533
# Epoch 151: loss did not improve from 0.00133
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 0.0031 - mae: 0.0531
# Epoch 152/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 0.0017 - mae: 0.0350
# Epoch 152: loss did not improve from 0.00133
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - loss: 0.0019 - mae: 0.0370
# Epoch 153/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 7.5175e-04 - mae: 0.0211
# Epoch 153: loss improved from 0.00133 to 0.00109, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 5s 2s/step - loss: 8.6582e-04 - mae: 0.0227
# Epoch 154/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0010 - mae: 0.0283
# Epoch 154: loss improved from 0.00109 to 0.00102, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 5s 2s/step - loss: 0.0010 - mae: 0.0284
# Epoch 155/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0022 - mae: 0.0427
# Epoch 155: loss did not improve from 0.00102
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step - loss: 0.0021 - mae: 0.0409
# Epoch 156/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 0.0032 - mae: 0.0522
# Epoch 156: loss did not improve from 0.00102
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - loss: 0.0031 - mae: 0.0509
# Epoch 157/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0020 - mae: 0.0408
# Epoch 157: loss did not improve from 0.00102
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 9s 2s/step - loss: 0.0020 - mae: 0.0408
# Epoch 158/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 7.7273e-04 - mae: 0.0234
# Epoch 158: loss did not improve from 0.00102
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - loss: 8.7289e-04 - mae: 0.0249
# Epoch 159/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 3.6631e-04 - mae: 0.0166
# Epoch 159: loss improved from 0.00102 to 0.00048, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 5s 2s/step - loss: 4.0270e-04 - mae: 0.0174
# Epoch 160/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 9.1813e-04 - mae: 0.0268
# Epoch 160: loss did not improve from 0.00048
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 5s 2s/step - loss: 8.7287e-04 - mae: 0.0259
# Epoch 161/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0014 - mae: 0.0333
# Epoch 161: loss did not improve from 0.00048
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - loss: 0.0013 - mae: 0.0318
# Epoch 162/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 9.5551e-04 - mae: 0.0292
# Epoch 162: loss did not improve from 0.00048
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 9.5131e-04 - mae: 0.0292
# Epoch 163/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 9.9961e-04 - mae: 0.0288
# Epoch 163: loss did not improve from 0.00048
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - loss: 9.9168e-04 - mae: 0.0287
# Epoch 164/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 3.0884e-04 - mae: 0.0147
# Epoch 164: loss improved from 0.00048 to 0.00041, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step - loss: 3.4142e-04 - mae: 0.0155
# Epoch 165/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 3.0999e-04 - mae: 0.0135
# Epoch 165: loss did not improve from 0.00041
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - loss: 3.6443e-04 - mae: 0.0147
# Epoch 166/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 1.7419e-04 - mae: 0.0108
# Epoch 166: loss improved from 0.00041 to 0.00020, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - loss: 1.8312e-04 - mae: 0.0110
# Epoch 167/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 3.9130e-04 - mae: 0.0169
# Epoch 167: loss did not improve from 0.00020
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 3.7556e-04 - mae: 0.0165
# Epoch 168/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 4.8159e-04 - mae: 0.0188
# Epoch 168: loss did not improve from 0.00020
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - loss: 4.5531e-04 - mae: 0.0181
# Epoch 169/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 3.9413e-04 - mae: 0.0178
# Epoch 169: loss did not improve from 0.00020
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - loss: 3.7585e-04 - mae: 0.0173
# Epoch 170/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 3.1132e-04 - mae: 0.0138
# Epoch 170: loss did not improve from 0.00020
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - loss: 2.9525e-04 - mae: 0.0133
# Epoch 171/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 9.6050e-05 - mae: 0.0083
# Epoch 171: loss improved from 0.00020 to 0.00011, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step - loss: 9.9852e-05 - mae: 0.0085
# Epoch 172/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 4.7235e-05 - mae: 0.0052
# Epoch 172: loss improved from 0.00011 to 0.00006, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - loss: 5.2552e-05 - mae: 0.0055
# Epoch 173/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 3.7680e-05 - mae: 0.0048
# Epoch 173: loss improved from 0.00006 to 0.00004, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 5s 2s/step - loss: 3.8138e-05 - mae: 0.0048
# Epoch 174/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 7.2044e-05 - mae: 0.0065
# Epoch 174: loss did not improve from 0.00004
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 6s 3s/step - loss: 7.0520e-05 - mae: 0.0064
# Epoch 175/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 1.6879e-04 - mae: 0.0119
# Epoch 175: loss did not improve from 0.00004
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 1.5966e-04 - mae: 0.0114
# Epoch 176/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 8.9163e-05 - mae: 0.0082
# Epoch 176: loss did not improve from 0.00004
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - loss: 8.7557e-05 - mae: 0.0082
# Epoch 177/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 5.7071e-05 - mae: 0.0059
# Epoch 177: loss did not improve from 0.00004
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step - loss: 6.0696e-05 - mae: 0.0062
# Epoch 178/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 4.0952e-05 - mae: 0.0054
# Epoch 178: loss did not improve from 0.00004
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 5s 2s/step - loss: 4.3593e-05 - mae: 0.0056
# Epoch 179/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 2.6372e-05 - mae: 0.0041
# Epoch 179: loss improved from 0.00004 to 0.00003, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 5s 2s/step - loss: 2.8597e-05 - mae: 0.0043
# Epoch 180/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 3.1810e-05 - mae: 0.0045
# Epoch 180: loss improved from 0.00003 to 0.00003, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - loss: 3.2022e-05 - mae: 0.0045
# Epoch 181/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 4.5997e-05 - mae: 0.0058
# Epoch 181: loss did not improve from 0.00003
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 4.4429e-05 - mae: 0.0057
# Epoch 182/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 6.1156e-05 - mae: 0.0070
# Epoch 182: loss did not improve from 0.00003
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - loss: 5.8529e-05 - mae: 0.0068
# Epoch 183/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 3.7277e-05 - mae: 0.0052
# Epoch 183: loss did not improve from 0.00003
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 9s 2s/step - loss: 3.6106e-05 - mae: 0.0051
# Epoch 184/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 4.5872e-05 - mae: 0.0059
# Epoch 184: loss did not improve from 0.00003
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - loss: 4.5501e-05 - mae: 0.0059
# Epoch 185/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 3.7022e-05 - mae: 0.0055
# Epoch 185: loss did not improve from 0.00003
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 9s 2s/step - loss:
300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 6.7788e-10 - mae: 1.4544e-05
# Epoch 271: loss did not improve from 0.00000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 8s 2s/step - loss: 7.2679e-10 - mae: 1.4782e-05
# Epoch 272/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 2.7649e-10 - mae: 5.0863e-06
# Epoch 272: loss improved from 0.00000 to 0.00000, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - loss: 3.4440e-10 - mae: 5.8280e-06
# Epoch 273/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 9.9681e-10 - mae: 1.7166e-05
# Epoch 273: loss did not improve from 0.00000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step - loss: 9.4587e-10 - mae: 1.6530e-05
# Epoch 274/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 4.7658e-10 - mae: 9.7752e-06
# Epoch 274: loss did not improve from 0.00000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 9s 2s/step - loss: 4.8749e-10 - mae: 1.0014e-05
# Epoch 275/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 4.9477e-10 - mae: 1.0808e-05
# Epoch 275: loss improved from 0.00000 to 0.00000, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 7s 2s/step - loss: 4.8506e-10 - mae: 1.0596e-05
# Epoch 276/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 4.8021e-10 - mae: 9.8546e-06
# Epoch 276: loss did not improve from 0.00000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 9s 2s/step - loss: 4.8506e-10 - mae: 9.9606e-06
# Epoch 277/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 4.4020e-10 - mae: 8.6625e-06
# Epoch 277: loss improved from 0.00000 to 0.00000, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step - loss: 4.1473e-10 - mae: 8.2122e-06
# Epoch 278/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 2.8255e-10 - mae: 5.6426e-06
# Epoch 278: loss improved from 0.00000 to 0.00000, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - loss: 2.8700e-10 - mae: 5.7750e-06
# Epoch 279/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 2.4496e-10 - mae: 4.9273e-06
# Epoch 279: loss improved from 0.00000 to 0.00000, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 5s 2s/step - loss: 2.2960e-10 - mae: 4.6624e-06
# Epoch 280/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 2.6679e-11 - mae: 9.5367e-07
# Epoch 280: loss improved from 0.00000 to 0.00000, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 6s 3s/step - loss: 2.5870e-11 - mae: 9.5367e-07
# Epoch 281/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 1.4673e-10 - mae: 3.0994e-06
# Epoch 281: loss did not improve from 0.00000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 8s 2s/step - loss: 1.8352e-10 - mae: 3.6558e-06
# Epoch 282/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 2.3041e-10 - mae: 3.1789e-06
# Epoch 282: loss did not improve from 0.00000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - loss: 2.9751e-10 - mae: 3.9207e-06
# Epoch 283/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 1.0671e-10 - mae: 1.9073e-06
# Epoch 283: loss did not improve from 0.00000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 9s 2s/step - loss: 1.0348e-10 - mae: 1.9073e-06
# Epoch 284/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 2.5223e-10 - mae: 5.0863e-06
# Epoch 284: loss did not improve from 0.00000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - loss: 2.3930e-10 - mae: 4.8743e-06
# Epoch 285/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 2.0858e-10 - mae: 3.1789e-06
# Epoch 285: loss did not improve from 0.00000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 5s 2s/step - loss: 2.5870e-10 - mae: 3.6028e-06
# Epoch 286/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 5.0689e-10 - mae: 7.4704e-06
# Epoch 286: loss did not improve from 0.00000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - loss: 4.9638e-10 - mae: 7.7354e-06
# Epoch 287/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 3.4925e-10 - mae: 9.8546e-06
# Epoch 287: loss did not improve from 0.00000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 3.2984e-10 - mae: 9.3248e-06
# Epoch 288/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 6.9122e-11 - mae: 2.4637e-06
# Epoch 288: loss did not improve from 0.00000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 5s 2s/step - loss: 8.0036e-11 - mae: 2.8080e-06
# Epoch 289/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 1.7705e-10 - mae: 4.2915e-06
# Epoch 289: loss did not improve from 0.00000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - loss: 1.7786e-10 - mae: 4.4505e-06
# Epoch 290/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 1.6735e-10 - mae: 4.2915e-06
# Epoch 290: loss did not improve from 0.00000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 1.6007e-10 - mae: 4.1326e-06
# Epoch 291/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 2.8861e-10 - mae: 6.3578e-06
# Epoch 291: loss did not improve from 0.00000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - loss: 2.7810e-10 - mae: 6.2519e-06
# Epoch 292/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 1.0186e-10 - mae: 2.0663e-06
# Epoch 292: loss did not improve from 0.00000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 9s 2s/step - loss: 1.2612e-10 - mae: 2.4372e-06
# Epoch 293/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 1.3946e-10 - mae: 3.2584e-06
# Epoch 293: loss did not improve from 0.00000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - loss: 1.3501e-10 - mae: 3.2319e-06
# Epoch 294/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 5.2144e-11 - mae: 2.3047e-06
# Epoch 294: loss did not improve from 0.00000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step - loss: 5.2549e-11 - mae: 2.2782e-06
# Epoch 295/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 2.4253e-11 - mae: 7.9473e-07
# Epoch 295: loss improved from 0.00000 to 0.00000, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step - loss: 2.2636e-11 - mae: 7.4175e-07
# Epoch 296/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 9.7013e-11 - mae: 1.5895e-06
# Epoch 296: loss did not improve from 0.00000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - loss: 9.0545e-11 - mae: 1.4835e-06
# Epoch 297/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 1.2127e-10 - mae: 2.3842e-06
# Epoch 297: loss did not improve from 0.00000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 9s 2s/step - loss: 1.1318e-10 - mae: 2.2252e-06
# Epoch 298/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 1.5765e-11 - mae: 7.1526e-07
# Epoch 298: loss did not improve from 0.00000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - loss: 1.8594e-11 - mae: 7.9473e-07
# Epoch 299/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 2.4253e-11 - mae: 7.9473e-07
# Epoch 299: loss did not improve from 0.00000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - loss: 2.2636e-11 - mae: 7.4175e-07
# Epoch 300/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 3.3954e-11 - mae: 1.1126e-06
# Epoch 300: loss did not improve from 0.00000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 3.5571e-11 - mae: 1.1656e-06

# %%
import zipfile
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.image import load_img, img_to_array
import matplotlib.pyplot as plt
import math

test_zip_path = '/content/test.zip'
test_extract_path = '/content/'

with zipfile.ZipFile(test_zip_path, 'r') as zip_ref:
    zip_ref.extractall(test_extract_path)

print(f'File berhasil diekstrak ke {test_extract_path}')

image_dir = '/content/test'

images = []
labels = []

for filename in os.listdir(image_dir):
    if filename.endswith(".jpg"):
        img_path = os.path.join(image_dir, filename)
        img = load_img(img_path, target_size=(224, 224))
        img_array = img_to_array(img) / 255.0

        label = int(filename.split('.')[0])

        images.append(img_array)
        labels.append(label)

X = np.array(images)
y = np.array(labels)


best_model = tf.keras.models.load_model('best_model.keras')
prediksi_bobot = best_model.predict(X)
selisih = np.abs(y - prediksi_bobot.flatten())
persentase_kebenaran = 100 * (1 - selisih / y)
rata_rata_persentase = np.mean(persentase_kebenaran)


num_images = len(X)
cols = 5
rows = math.ceil(num_images / cols)

plt.figure(figsize=(cols * 3, rows * 3))

for i in range(num_images):
    plt.subplot(rows, cols, i + 1)
    plt.imshow(X[i])
    plt.axis('off')
    plt.title(f"Aktual: {y[i]} kg\nPrediksi: {prediksi_bobot[i][0]:.2f} kg\nSelisih: {selisih[i]:.2f} kg\nKebenaran: {persentase_kebenaran[i]:.2f}%", fontsize=8, color='black')

plt.suptitle(f"Rata-rata Persentase Kebenaran: {rata_rata_persentase:.2f}%", fontsize=12, y=1.02)
plt.tight_layout()
plt.show()
# Out:
# File berhasil diekstrak ke /content/
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 314ms/step

# %%
import zipfile
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.image import load_img, img_to_array
import matplotlib.pyplot as plt
import math
import cv2

# Ekstrak file ZIP test
test_zip_path = '/content/test.zip'
test_extract_path = '/content/'

with zipfile.ZipFile(test_zip_path, 'r') as zip_ref:
    zip_ref.extractall(test_extract_path)

print(f'File berhasil diekstrak ke {test_extract_path}')

# Load model segmentasi
segmentation_model = tf.keras.models.load_model('/content/segmentasi_model_unet_best.h5')

# Folder dataset
test_image_dir = '/content/test'
test_segmented_dir = '/content/test_segmented'
os.makedirs(test_segmented_dir, exist_ok=True)

SEGMENTATION_IMG_HEIGHT, SEGMENTATION_IMG_WIDTH = 256, 256
PREDICTION_IMG_HEIGHT, PREDICTION_IMG_WIDTH = 224, 224

def segment_image(image_path):
    image = cv2.imread(image_path)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    image = cv2.resize(image, (SEGMENTATION_IMG_WIDTH, SEGMENTATION_IMG_HEIGHT)) / 255.0
    image_input = np.expand_dims(image, axis=0)
    pred_mask = segmentation_model.predict(image_input)[0]
    pred_mask = (pred_mask > 0.5).astype(np.uint8)

    segmented_image = image * np.expand_dims(pred_mask[:, :, 0], axis=-1)
    return segmented_image

images = []
labels = []

for filename in os.listdir(test_image_dir):
    if filename.endswith(".jpg"):
        img_path = os.path.join(test_image_dir, filename)
        segmented_image = segment_image(img_path)
        segmented_path = os.path.join(test_segmented_dir, filename)
        cv2.imwrite(segmented_path, cv2.cvtColor((segmented_image * 255).astype(np.uint8), cv2.COLOR_RGB2BGR))

        img_array = img_to_array(load_img(segmented_path, target_size=(PREDICTION_IMG_HEIGHT, PREDICTION_IMG_WIDTH))) / 255.0
        label = int(filename.split('.')[0])

        images.append(img_array)
        labels.append(label)

X = np.array(images)
y = np.array(labels)

# Load model prediksi bobot sapi
best_model = tf.keras.models.load_model('best_model.keras')
prediksi_bobot = best_model.predict(X)
selisih = np.abs(y - prediksi_bobot.flatten())
persentase_kebenaran = 100 * (1 - selisih / y)
rata_rata_persentase = np.mean(persentase_kebenaran)

num_images = len(X)
cols = 5
rows = math.ceil(num_images / cols)

plt.figure(figsize=(cols * 3, rows * 3))

for i in range(num_images):
    plt.subplot(rows, cols, i + 1)
    plt.imshow(X[i])
    plt.axis('off')
    plt.title(f"Aktual: {y[i]} kg\nPrediksi: {prediksi_bobot[i][0]:.2f} kg\nSelisih: {selisih[i]:.2f} kg\nKebenaran: {persentase_kebenaran[i]:.2f}%", fontsize=8, color='black')

plt.suptitle(f"Rata-rata Persentase Kebenaran: {rata_rata_persentase:.2f}%", fontsize=12, y=1.02)
plt.tight_layout()
plt.show()
# Out:
# File berhasil diekstrak ke /content/
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step
