# %%
import pandas as pd
import tensorflow as tf
from tensorflow.keras.preprocessing.image import load_img, img_to_array, ImageDataGenerator
import numpy as np
import os
import zipfile
import cv2
import matplotlib.pyplot as plt

# %%
# Ekstrak file ZIP
zip_path = '/content/dataset2.zip'
extract_path = '/content/'

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

print(f'File berhasil diekstrak ke {extract_path}')

# Load model segmentasi
segmentation_model = tf.keras.models.load_model('/content/segmentasi_model_unet_best.h5')
# Out:
# File berhasil diekstrak ke /content/
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
# Folder dataset
image_dir = '/content/dataset2'
segmented_dir = '/content/dataset2_segmented'
os.makedirs(segmented_dir, exist_ok=True)

SEGMENTATION_IMG_HEIGHT, SEGMENTATION_IMG_WIDTH = 256, 256
PREDICTION_IMG_HEIGHT, PREDICTION_IMG_WIDTH = 224, 224

# Data augmentation settings
data_gen = ImageDataGenerator(
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.1,
    zoom_range=0.1,
    fill_mode='nearest'
)

def segment_image(image_path):
    image = cv2.imread(image_path)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    image = cv2.resize(image, (SEGMENTATION_IMG_HEIGHT, SEGMENTATION_IMG_WIDTH)) / 255.0
    image_input = np.expand_dims(image, axis=0)
    pred_mask = segmentation_model.predict(image_input)[0]
    pred_mask = (pred_mask > 0.5).astype(np.uint8)
    return pred_mask[:, :, 0]  # Mask biner

images = []
labels = []

# %%
for filename in os.listdir(image_dir):
    if filename.endswith(".jpg"):
        img_path = os.path.join(image_dir, filename)
        mask = segment_image(img_path)
        segmented_path = os.path.join(segmented_dir, filename)
        cv2.imwrite(segmented_path, mask * 255)

        # Load segmented image
        img_array = img_to_array(load_img(segmented_path, target_size=(PREDICTION_IMG_HEIGHT, PREDICTION_IMG_WIDTH))) / 255.0
        label = int(filename.split('.')[0])

        # Tambahkan gambar asli
        images.append(img_array.astype(np.float32))
        labels.append(label)

        # Augmentasi sebanyak 3 kali
        img_array_expanded = np.expand_dims(img_array, axis=0)
        augmented_images = data_gen.flow(img_array_expanded, batch_size=1)

        for _ in range(3):
            aug_img = next(augmented_images)[0]  # Ambil batch pertama
            images.append(aug_img.astype(np.float32))
            labels.append(label)

X = np.array(images)
y = np.array(labels)

print(f"Total gambar setelah augmentasi: {len(X)}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Total gambar setelah augmentasi: 64

# %%
# Model sederhana
model = tf.keras.Sequential([
    tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(PREDICTION_IMG_HEIGHT, PREDICTION_IMG_WIDTH, 3)),
    tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
    tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
    tf.keras.layers.Conv2D(128, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(1, activation='linear')
])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mae'])

checkpoint = tf.keras.callbacks.ModelCheckpoint(
    'best_model.keras',
    monitor='loss',
    save_best_only=True,
    mode='min',
    verbose=1
)

history = model.fit(
    X, y,
    epochs=300,
    batch_size=32,
    callbacks=[checkpoint]
)
# Out:
# Epoch 1/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 247317.5469 - mae: 443.2755
# Epoch 1: loss improved from inf to 232045.56250, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 4s/step - loss: 242226.8906 - mae: 438.2975
# Epoch 2/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 179342.6562 - mae: 351.5621
# Epoch 2: loss improved from 232045.56250 to 161052.31250, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 11s 4s/step - loss: 173245.8750 - mae: 345.4231
# Epoch 3/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - loss: 84857.1250 - mae: 210.8858
# Epoch 3: loss improved from 161052.31250 to 80587.26562, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 5s/step - loss: 83433.8438 - mae: 213.6912
# Epoch 4/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 84716.5625 - mae: 256.7279
# Epoch 4: loss improved from 80587.26562 to 77708.14062, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 9s 4s/step - loss: 82380.4219 - mae: 252.2878
# Epoch 5/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 57440.2344 - mae: 174.6624
# Epoch 5: loss improved from 77708.14062 to 56941.12891, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 8s 4s/step - loss: 57273.8633 - mae: 172.0482
# Epoch 6/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - loss: 68668.3125 - mae: 172.0330
# Epoch 6: loss did not improve from 56941.12891
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 4s/step - loss: 68759.4766 - mae: 172.1463
# Epoch 7/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 56951.3672 - mae: 153.2707
# Epoch 7: loss did not improve from 56941.12891
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 9s 3s/step - loss: 58256.9102 - mae: 156.0827
# Epoch 8/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 47445.3281 - mae: 167.7118
# Epoch 8: loss improved from 56941.12891 to 50803.47656, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 11s 4s/step - loss: 48564.7109 - mae: 170.9814
# Epoch 9/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 57742.4023 - mae: 207.8642
# Epoch 9: loss did not improve from 50803.47656
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 8s 3s/step - loss: 58024.3086 - mae: 209.0078
# Epoch 10/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - loss: 56397.5000 - mae: 204.5222
# Epoch 10: loss did not improve from 50803.47656
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 5s/step - loss: 55913.5430 - mae: 203.2636
# Epoch 11/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 49406.7266 - mae: 173.4946
# Epoch 11: loss did not improve from 50803.47656
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 9s 3s/step - loss: 50199.9492 - mae: 173.7898
# Epoch 12/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 47391.4609 - mae: 143.0908
# Epoch 12: loss did not improve from 50803.47656
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - loss: 49342.1211 - mae: 147.9187
# Epoch 13/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 55454.3828 - mae: 160.7371
# Epoch 13: loss improved from 50803.47656 to 50569.32812, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 11s 4s/step - loss: 53826.0312 - mae: 160.4773
# Epoch 14/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - loss: 45588.9141 - mae: 170.8493
# Epoch 14: loss improved from 50569.32812 to 47089.78906, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 8s 5s/step - loss: 46089.2070 - mae: 172.4599
# Epoch 15/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 49574.4492 - mae: 193.4963
# Epoch 15: loss did not improve from 47089.78906
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 8s 3s/step - loss: 48763.4336 - mae: 190.8334
# Epoch 16/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 44485.9883 - mae: 177.9608
# Epoch 16: loss improved from 47089.78906 to 45167.73438, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 8s 4s/step - loss: 44713.2383 - mae: 177.8158
# Epoch 17/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - loss:
# Epoch 41/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - loss: 5413.3867 - mae: 55.3840
# Epoch 41: loss improved from 5674.01074 to 4926.33301, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 5s/step - loss: 5251.0356 - mae: 54.5954
# Epoch 42/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 3777.3130 - mae: 47.4343
# Epoch 42: loss improved from 4926.33301 to 3877.37280, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 9s 4s/step - loss: 3810.6663 - mae: 47.5337
# Epoch 43/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 3220.5547 - mae: 41.3503
# Epoch 43: loss improved from 3877.37280 to 3047.47534, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 4s/step - loss: 3162.8616 - mae: 41.4584
# Epoch 44/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 2537.5967 - mae: 37.3496
# Epoch 44: loss improved from 3047.47534 to 2435.29395, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 4s/step - loss: 2503.4958 - mae: 37.0550
# Epoch 45/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 2604.2361 - mae: 37.9053
# Epoch 45: loss improved from 2435.29395 to 2286.76807, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 11s 4s/step - loss: 2498.4133 - mae: 36.9430
# Epoch 46/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - loss: 1949.3333 - mae: 32.8488
# Epoch 46: loss improved from 2286.76807 to 1714.93530, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 11s 4s/step - loss: 1871.2006 - mae: 31.9267
# Epoch 47/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - loss: 1613.0393 - mae: 29.6440
# Epoch 47: loss improved from 1714.93530 to 1649.38965, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 4s/step - loss: 1625.1561 - mae: 29.7756
# Epoch 48/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 1480.4910 - mae: 29.7952
# Epoch 48: loss improved from 1649.38965 to 1408.56763, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 7s 4s/step - loss: 1456.5166 - mae: 29.5562
# Epoch 49/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 924.5049 - mae: 21.5234
# Epoch 49: loss improved from 1408.56763 to 1076.47131, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 11s 4s/step - loss: 975.1604 - mae: 22.1728
# Epoch 50/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 959.8044 - mae: 23.2536
# Epoch 50: loss improved from 1076.47131 to 1064.37048, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 7s 4s/step - loss: 994.6598 - mae: 23.6879
# Epoch 51/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 1048.1143 - mae: 25.2434
# Epoch 51: loss improved from 1064.37048 to 1013.19623, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 4s/step - loss: 1036.4749 - mae: 25.1875
# Epoch 52/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 882.0880 - mae: 22.7081
# Epoch 52: loss improved from 1013.19623 to 932.94855, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 4s/step - loss: 899.0416 - mae: 22.9615
# Epoch 53/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 706.2295 - mae: 20.9911
# Epoch 53: loss improved from 932.94855 to 738.09155, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 11s 4s/step - loss: 716.8502 - mae: 21.1626
# Epoch 54/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - loss: 726.1070 - mae: 20.5098
# Epoch 54: loss improved from 738.09155 to 583.73138, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 8s 5s/step - loss: 678.6484 - mae: 19.7202
# Epoch 55/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 559.2603 - mae: 17.9133
# Epoch 55: loss improved from 583.73138 to 538.65527, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 7s 4s/step - loss: 552.3919 - mae: 17.8009
# Epoch 56/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 379.1130 - mae: 14.0594
# Epoch 56: loss improved from 538.65527 to 431.27863, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 11s 4s/step - loss: 396.5015 - mae: 14.5977
# Epoch 57/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 282.7098 - mae: 12.5869
# Epoch 57: loss improved from 431.27863 to 330.99310, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 11s 4s/step - loss: 298.8042 - mae: 12.8574
# Epoch 58/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - loss: 282.3605 - mae: 12.8411
# Epoch 58: loss improved from 330.99310 to 288.45538, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 5s/step - loss: 284.3921 - mae: 12.7916
# Epoch 59/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 278.7097 - mae: 13.4025
# Epoch 59: loss improved from 288.45538 to 277.95807, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 9s 4s/step - loss: 278.4592 - mae: 13.3349
# Epoch 60/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 214.3893 - mae: 11.3005
# Epoch 60: loss improved from 277.95807 to 223.60605, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 8s 4s/step - loss: 217.4615 - mae: 11.3146
# Epoch 61/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - loss: 186.6501 - mae: 10.3267
# Epoch 61: loss improved from 223.60605 to 194.47670, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 5s/step - loss: 189.2589 - mae: 10.4812
# Epoch 62/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 159.1032 - mae: 10.1188
# Epoch 62: loss improved from 194.47670 to 160.12602, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 9s 4s/step - loss: 159.4442 - mae: 10.0237
# Epoch 63/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 113.7391 - mae: 8.1574
# Epoch 63: loss improved from 160.12602 to 124.87329, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 8s 4s/step - loss: 117.4505 - mae: 8.2552
# Epoch 64/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 114.6368 - mae: 8.7138
# Epoch 64: loss improved from 124.87329 to 102.06711, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 7s 4s/step - loss: 110.4469 - mae: 8.4699
# Epoch 65/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 77.3986 - mae: 6.7095
# Epoch 65: loss improved from 102.06711 to 92.89697, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 4s/step - loss: 82.5647 - mae: 6.8840
# Epoch 66/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 59.4036 - mae: 5.6596
# Epoch 66: loss improved from 92.89697 to 65.18912, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 8s 4s/step - loss: 61.3321 - mae: 5.7879
# Epoch 67/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 70.0607 - mae: 6.7654
# Epoch 67: loss improved from 65.18912 to 63.62276, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 7s 4s/step - loss: 67.9147 - mae: 6.5977
# Epoch 68/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 48.1669 - mae: 5.1940
# Epoch 68: loss improved from 63.62276 to 49.03472, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 4s/step - loss: 48.4562 - mae: 5.2009
# Epoch 69/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 37.9558 - mae: 4.5674
# Epoch 69: loss improved from 49.03472 to 42.22339, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 4s/step - loss: 39.3784 - mae: 4.6977
# Epoch 70/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 35.0160 - mae: 4.3769
# Epoch 70: loss improved from 42.22339 to 33.78409, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 11s 4s/step - loss: 34.6054 - mae: 4.3606
# Epoch 71/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - loss: 34.6387 - mae: 4.6699
# Epoch 71: loss did not improve from 33.78409
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 7s 4s/step - loss: 34.9642 - mae: 4.6953
# Epoch 72/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 24.0680 - mae: 3.8766
# Epoch 72: loss improved from 33.78409 to 23.37714, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 4s/step - loss: 23.8377 - mae: 3.8435
# Epoch 73/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 20.7653 - mae: 3.4742
# Epoch 73: loss improved from 23.37714 to 20.99014, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 4s/step - loss: 20.8403 - mae: 3.4601
# Epoch 74/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 19.8249 - mae: 3.5930
# Epoch 74: loss did not improve from 20.99014
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - loss: 20.4188 - mae: 3.6443
# Epoch 75/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 14.9452 - mae: 2.7029
# Epoch 75: loss improved from 20.99014 to 19.89788, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 12s 4s/step - loss: 16.5961 - mae: 2.8952
# Epoch 76/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - loss: 14.4814 - mae: 2.8705
# Epoch 76: loss improved from 19.89788 to 18.92887, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 8s 5s/step - loss: 15.9639 - mae: 3.0664
# Epoch 77/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 13.6225 - mae: 2.8280
# Epoch 77: loss improved from 18.92887 to 14.51942, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 7s 4s/step - loss: 13.9215 - mae: 2.8676
# Epoch 78/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - loss: 14.9124 - mae: 2.9798
# Epoch 78: loss improved from 14.51942 to 13.16174, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 8s 5s/step - loss: 14.3289 - mae: 2.9136
# Epoch 79/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 14.4479 - mae: 3.2704
# Epoch 79: loss improved from 13.16174 to 11.76050, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 7s 4s/step - loss: 13.5521 - mae: 3.1356
# Epoch 80/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 9.4684 - mae: 2.4733
# Epoch 80: loss improved from 11.76050 to 8.72057, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 4s/step - loss: 9.2191 - mae: 2.4409
# Epoch 81/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 9.0994 - mae: 2.5050
# Epoch 81: loss improved from 8.72057 to 7.73128, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 11s 4s/step - loss: 8.6433 - mae: 2.4349
# Epoch 82/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 4.7496 - mae: 1.5989
# Epoch 82: loss improved from 7.73128 to 6.00107, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 7s 4s/step - loss: 5.1668 - mae: 1.6976
# Epoch 83/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 3.4754 - mae: 1.3993
# Epoch 83: loss improved from 6.00107 to 4.82314, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 7s 4s/step - loss: 3.9246 - mae: 1.4908
# Epoch 84/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 2.6554 - mae: 1.3359
# Epoch 84: loss improved from 4.82314 to 2.80173, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 11s 4s/step - loss: 2.7042 - mae: 1.3490
# Epoch 85/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 3.4312 - mae: 1.4995
# Epoch 85: loss improved from 2.80173 to 2.77057, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 7s 4s/step - loss: 3.2110 - mae: 1.4389
# Epoch 86/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 3.3570 - mae: 1.5273
# Epoch 86: loss did not improve from 2.77057
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - loss: 3.2089 - mae: 1.4890
# Epoch 87/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 3.4687 - mae: 1.5162
# Epoch 87: loss did not improve from 2.77057
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - loss: 3.3676 - mae: 1.5031
# Epoch 88/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 2.2018 - mae: 1.1346
# Epoch 88: loss did not improve from 2.77057
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 11s 3s/step - loss: 2.5107 - mae: 1.2342
# Epoch 89/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - loss: 1.5537 - mae: 1.0132
# Epoch 89: loss improved from 2.77057 to 2.10222, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 7s 4s/step - loss: 1.7365 - mae: 1.0774
# Epoch 90/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 1.1857 - mae: 0.8890
# Epoch 90: loss improved from 2.10222 to 1.34600, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 7s 4s/step - loss: 1.2391 - mae: 0.9134
# Epoch 91/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 1.5379 - mae: 1.0276
# Epoch 91: loss improved from 1.34600 to 1.23015, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 11s 4s/step - loss: 1.4353 - mae: 0.9836
# Epoch 92/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 1.7518 - mae: 1.1522
# Epoch 92: loss did not improve from 1.23015
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 6s 3s/step - loss: 1.6257 - mae: 1.0949
# Epoch 93/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 1.4681 - mae: 1.0070
# Epoch 93: loss did not improve from 1.23015
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - loss: 1.4044 - mae: 0.9809
# Epoch 94/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 0.9896 - mae: 0.8446
# Epoch 94: loss improved from 1.23015 to 0.98382, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 11s 4s/step - loss: 0.9877 - mae: 0.8487
# Epoch 95/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - loss: 0.6723 - mae: 0.6587
# Epoch 95: loss improved from 0.98382 to 0.94236, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 8s 4s/step - loss: 0.7623 - mae: 0.7075
# Epoch 96/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 0.4776 - mae: 0.5424
# Epoch 96: loss improved from 0.94236 to 0.56549, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 9s 4s/step - loss: 0.5069 - mae: 0.5652
# Epoch 97/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 0.4218 - mae: 0.5256
# Epoch 97: loss improved from 0.56549 to 0.45115, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 7s 4s/step - loss: 0.4316 - mae: 0.5368
# Epoch 98/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 0.4459 - mae: 0.5497
# Epoch 98: loss improved from 0.45115 to 0.39844, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 11s 4s/step - loss: 0.4301 - mae: 0.5333
# Epoch 99/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - loss: 0.4662 - mae: 0.5629
# Epoch 99: loss improved from 0.39844 to 0.37521, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 5s/step - loss: 0.4359 - mae: 0.5374
# Epoch 100/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 0.6099 - mae: 0.6746
# Epoch 100: loss did not improve from 0.37521
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 6s 3s/step - loss: 0.5669 - mae: 0.6401
# Epoch 101/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 0.4751 - mae: 0.6036
# Epoch 101: loss did not improve from 0.37521
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 11s 3s/step - loss: 0.4616 - mae: 0.5890
# Epoch 102/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - loss: 0.3424 - mae: 0.4936
# Epoch 102: loss did not improve from 0.37521
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 11s 4s/step - loss: 0.3678 - mae: 0.5158
# Epoch 103/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 0.3134 - mae: 0.4509
# Epoch 103: loss did not improve from 0.37521
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 9s 3s/step - loss: 0.3585 - mae: 0.4900
# Epoch 104/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 0.2885 - mae: 0.4439
# Epoch 104: loss did not improve from 0.37521
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - loss: 0.3375 - mae: 0.4871
# Epoch 105/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 0.2280 - mae: 0.3648
# Epoch 105: loss improved from 0.37521 to 0.37332, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 11s 4s/step - loss: 0.2765 - mae: 0.4077
# Epoch 106/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - loss: 0.1329 - mae: 0.2750
# Epoch 106: loss improved from 0.37332 to 0.21544, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 8s 4s/step - loss: 0.1604 - mae: 0.3069
# Epoch 107/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 0.1687 - mae: 0.3613
# Epoch 107: loss improved from 0.21544 to 0.19550, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 9s 4s/step - loss: 0.1776 - mae: 0.3729
# Epoch 108/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 0.1716 - mae: 0.3694
# Epoch 108: loss improved from 0.19550 to 0.16970, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 4s/step - loss: 0.1710 - mae: 0.3648
# Epoch 109/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 0.2491 - mae: 0.4081
# Epoch 109: loss did not improve from 0.16970
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - loss: 0.2272 - mae: 0.3826
# Epoch 110/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - loss: 0.2851 - mae: 0.4863
# Epoch 110: loss did not improve from 0.16970
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 7s 4s/step - loss: 0.2595 - mae: 0.4540
# Epoch 111/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 0.2056 - mae: 0.3983
# Epoch 111: loss improved from 0.16970 to 0.15236, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 4s/step - loss: 0.1878 - mae: 0.3739
# Epoch 112/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 0.2151 - mae: 0.4044
# Epoch 112: loss did not improve from 0.15236
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 9s 3s/step - loss: 0.1971 - mae: 0.3801
# Epoch 113/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 0.1475 - mae: 0.3324
# Epoch 113: loss improved from 0.15236 to 0.11934, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 11s 4s/step - loss: 0.1381 - mae: 0.3182
# Epoch 114/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - loss: 0.1444 - mae: 0.3201
# Epoch 114: loss improved from 0.11934 to 0.11497, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 8s 5s/step - loss: 0.1346 - mae: 0.3049
# Epoch 115/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 0.0997 - mae: 0.2775
# Epoch 115: loss improved from 0.11497 to 0.10561, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 7s 4s/step - loss: 0.1016 - mae: 0.2798
# Epoch 116/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 0.1209 - mae: 0.3041
# Epoch 116: loss improved from 0.10561 to 0.09535, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 8s 4s/step - loss: 0.1124 - mae: 0.2904
# Epoch 117/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - loss: 0.0458 - mae: 0.1778
# Epoch 117: loss improved from 0.09535 to 0.04779, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 5s/step - loss: 0.0465 - mae: 0.1788
# Epoch 118/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 0.0299 - mae: 0.1314
# Epoch 118: loss improved from 0.04779 to 0.04172, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 7s 4s/step - loss: 0.0338 - mae: 0.1415
# Epoch 119/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 0.0300 - mae: 0.1459
# Epoch 119: loss improved from 0.04172 to 0.03720, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 11s 4s/step - loss: 0.0324 - mae: 0.1531
# Epoch 120/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - loss: 0.0214 - mae: 0.1071
# Epoch 120: loss improved from 0.03720 to 0.03503, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 5s/step - loss: 0.0259 - mae: 0.1196
# Epoch 121/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 0.0242 - mae: 0.1179
# Epoch 121: loss did not improve from 0.03503
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 6s 3s/step - loss: 0.0296 - mae: 0.1321
# Epoch 122/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 0.0217 - mae: 0.1180
# Epoch 122: loss improved from 0.03503 to 0.03115, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 11s 4s/step - loss: 0.0248 - mae: 0.1269
# Epoch 123/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 0.0140 - mae: 0.0903
# Epoch 123: loss improved from 0.03115 to 0.01843, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 11s 4s/step - loss: 0.0155 - mae: 0.0956
# Epoch 124/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - loss: 0.0188 - mae: 0.1124
# Epoch 124: loss did not improve from 0.01843
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 4s/step - loss: 0.0204 - mae: 0.1180
# Epoch 125/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 0.0098 - mae: 0.0799
# Epoch 125: loss improved from 0.01843 to 0.01104, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 4s/step - loss: 0.0102 - mae: 0.0817
# Epoch 126/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 0.0170 - mae: 0.1094
# Epoch 126: loss did not improve from 0.01104
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 9s 3s/step - loss: 0.0171 - mae: 0.1102
# Epoch 127/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 0.0134 - mae: 0.1018
# Epoch 127: loss did not improve from 0.01104
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - loss: 0.0132 - mae: 0.1008
# Epoch 128/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - loss: 0.0071 - mae: 0.0741
# Epoch 128: loss improved from 0.01104 to 0.00667, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 8s 5s/step - loss: 0.0070 - mae: 0.0725
# Epoch 129/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 0.0140 - mae: 0.0980
# Epoch 129: loss did not improve from 0.00667
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 6s 3s/step - loss: 0.0131 - mae: 0.0936
# Epoch 130/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 0.0100 - mae: 0.0781
# Epoch 130: loss did not improve from 0.00667
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - loss: 0.0091 - mae: 0.0728
# Epoch 131/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 0.0075 - mae: 0.0717
# Epoch 131: loss improved from 0.00667 to 0.00573, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 12s 4s/step - loss: 0.0069 - mae: 0.0680
# Epoch 132/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - loss: 0.0076 - mae: 0.0705
# Epoch 132: loss did not improve from 0.00573
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 4s/step - loss: 0.0070 - mae: 0.0672
# Epoch 133/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 0.0043 - mae: 0.0548
# Epoch 133: loss improved from 0.00573 to 0.00358, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 4s/step - loss: 0.0041 - mae: 0.0531
# Epoch 134/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 0.0048 - mae: 0.0584
# Epoch 134: loss did not improve from 0.00358
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 7s 3s/step - loss: 0.0046 - mae: 0.0566
# Epoch 135/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 0.0050 - mae: 0.0631
# Epoch 135: loss did not improve from 0.00358
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 11s 3s/step - loss: 0.0048 - mae: 0.0623
# Epoch 136/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - loss: 0.0088 - mae: 0.0788
# Epoch 136: loss did not improve from 0.00358
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 4s/step - loss: 0.0080 - mae: 0.0733
# Epoch 137/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 0.0039 - mae: 0.0554
# Epoch 137: loss improved from 0.00358 to 0.00295, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 4s/step - loss: 0.0036 - mae: 0.0521
# Epoch 138/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 0.0030 - mae: 0.0489
# Epoch 138: loss improved from 0.00295 to 0.00238, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 4s/step - loss: 0.0028 - mae: 0.0465
# Epoch 139/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 0.0032 - mae: 0.0467
# Epoch 139: loss did not improve from 0.00238
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - loss: 0.0030 - mae: 0.0440
# Epoch 140/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 0.0021 - mae: 0.0384
# Epoch 140: loss improved from 0.00238 to 0.00157, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 12s 4s/step - loss: 0.0019 - mae: 0.0360
# Epoch 141/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - loss: 0.0022 - mae: 0.0404
# Epoch 141: loss did not improve from 0.00157
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 4s/step - loss: 0.0020 - mae: 0.0380
# Epoch 142/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 0.0016 - mae: 0.0328
# Epoch 142: loss improved from 0.00157 to 0.00127, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 7s 4s/step - loss: 0.0015 - mae: 0.0312
# Epoch 143/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 0.0015 - mae: 0.0317
# Epoch 143: loss improved from 0.00127 to 0.00114, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 4s/step - loss: 0.0014 - mae: 0.0298
# Epoch 144/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - loss: 0.0015 - mae: 0.0335
# Epoch 144: loss did not improve from 0.00114
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 8s 4s/step - loss: 0.0014 - mae: 0.0316
# Epoch 145/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 0.0016 - mae: 0.0329
# Epoch 145: loss did not improve from 0.00114
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 6s 3s/step - loss: 0.0015 - mae: 0.0308
# Epoch 146/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - loss: 0.0021 - mae: 0.0412
# Epoch 146: loss did not improve from 0.00114
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 7s 4s/step - loss: 0.0019 - mae: 0.0381
# Epoch 147/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 0.0012 - mae: 0.0309
# Epoch 147: loss improved from 0.00114 to 0.00089, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 9s 4s/step - loss: 0.0011 - mae: 0.0290
# Epoch 148/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 0.0016 - mae: 0.0334
# Epoch 148: loss did not improve from 0.00089
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 7s 3s/step - loss: 0.0015 - mae: 0.0316
# Epoch 149/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - loss: 0.0024 - mae: 0.0428
# Epoch 149: loss did not improve from 0.00089
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 4s/step - loss: 0.0022 - mae: 0.0400
# Epoch 150/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 0.0017 - mae: 0.0364
# Epoch 150: loss did not improve from 0.00089
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 9s 3s/step - loss: 0.0015 - mae: 0.0341
# Epoch 151/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 0.0023 - mae: 0.0424
# Epoch 151: loss did not improve from 0.00089
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - loss: 0.0021 - mae: 0.0393
# Epoch 152/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 0.0019 - mae: 0.0395
# Epoch 152: loss did not improve from 0.00089
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - loss: 0.0018 - mae: 0.0373
# Epoch 153/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - loss: 9.1287e-04 - mae: 0.0260
# Epoch 153: loss improved from 0.00089 to 0.00074, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 8s 5s/step - loss: 8.5675e-04 - mae: 0.0250
# Epoch 154/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 6.0090e-04 - mae: 0.0218
# Epoch 154: loss improved from 0.00074 to 0.00053, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 9s 4s/step - loss: 5.7733e-04 - mae: 0.0211
# Epoch 155/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 6.4802e-04 - mae: 0.0225
# Epoch 155: loss improved from 0.00053 to 0.00053, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 4s/step - loss: 6.0866e-04 - mae: 0.0215
# Epoch 156/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 6.2361e-04 - mae: 0.0213
# Epoch 156: loss improved from 0.00053 to 0.00052, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 8s 4s/step - loss: 5.9009e-04 - mae: 0.0206
# Epoch 157/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 6.5097e-04 - mae: 0.0223
# Epoch 157: loss did not improve from 0.00052
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 6s 3s/step - loss: 6.3096e-04 - mae: 0.0218
# Epoch 158/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 5.3491e-04 - mae: 0.0203
# Epoch 158: loss did not improve from 0.00052
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 7s 3s/step - loss: 5.3154e-04 - mae: 0.0203
# Epoch 159/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - loss: 4.6290e-04 - mae: 0.0187
# Epoch 159: loss did not improve from 0.00052
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 4s/step - loss: 4.9463e-04 - mae: 0.0193
# Epoch 160/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 1.8474e-04 - mae: 0.0108
# Epoch 160: loss improved from 0.00052 to 0.00024, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 9s 4s/step - loss: 2.0183e-04 - mae: 0.0114
# Epoch 161/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 2.1214e-04 - mae: 0.0120
# Epoch 161: loss did not improve from 0.00024
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - loss: 2.3079e-04 - mae: 0.0126
# Epoch 162/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 1.8650e-04 - mae: 0.0112
# Epoch 162: loss did not improve from 0.00024
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - loss: 2.0795e-04 - mae: 0.0119
# Epoch 163/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - loss: 1.8976e-04 - mae: 0.0115
# Epoch 163: loss did not improve from 0.00024
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 7s 4s/step - loss: 2.1477e-04 - mae: 0.0123
# Epoch 164/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 1.9239e-04 - mae: 0.0101
# Epoch 164: loss did not improve from 0.00024
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 6s 3s/step - loss: 2.3779e-04 - mae: 0.0114
# Epoch 165/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - loss: 2.2693e-04 - mae: 0.0138
# Epoch 165: loss did not improve from 0.00024
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 7s 4s/step - loss: 2.3331e-04 - mae: 0.0140
# Epoch 166/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 2.1952e-04 - mae: 0.0124
# Epoch 166: loss improved from 0.00024 to 0.00023, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 9s 4s/step - loss: 2.2411e-04 - mae: 0.0126
# Epoch 167/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 3.2702e-04 - mae: 0.0156
# Epoch 167: loss did not improve from 0.00023
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - loss: 2.9734e-04 - mae: 0.0146
# Epoch 168/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - loss: 2.0532e-04 - mae: 0.0120
# Epoch 168: loss improved from 0.00023 to 0.00014, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 8s 4s/step - loss: 1.8505e-04 - mae: 0.0111
# Epoch 169/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 1.7829e-04 - mae: 0.0119
# Epoch 169: loss improved from 0.00014 to 0.00014, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 7s 4s/step - loss: 1.6551e-04 - mae: 0.0113
# Epoch 170/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 1.7436e-04 - mae: 0.0118
# Epoch 170: loss did not improve from 0.00014
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - loss: 1.6897e-04 - mae: 0.0115
# Epoch 171/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 8.1737e-05 - mae: 0.0074
# Epoch 171: loss improved from 0.00014 to 0.00009, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 11s 4s/step - loss: 8.3941e-05 - mae: 0.0076
# Epoch 172/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 2.6789e-05 - mae: 0.0041
# Epoch 172: loss improved from 0.00009 to 0.00004, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 11s 4s/step - loss: 2.9622e-05 - mae: 0.0043
# Epoch 173/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - loss: 6.5601e-05 - mae: 0.0068
# Epoch 173: loss did not improve from 0.00004
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 9s 4s/step - loss: 6.8534e-05 - mae: 0.0069
# Epoch 174/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 5.2061e-05 - mae: 0.0057
# Epoch 174: loss did not improve from 0.00004
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 9s 3s/step - loss: 5.8473e-05 - mae: 0.0061
# Epoch 175/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 4.0318e-05 - mae: 0.0050
# Epoch 175: loss did not improve from 0.00004
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - loss: 4.4661e-05 - mae: 0.0054
# Epoch 176/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 3.2152e-05 - mae: 0.0045
# Epoch 176: loss did not improve from 0.00004
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - loss: 3.4463e-05 - mae: 0.0046
# Epoch 177/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 3.5760e-05 - mae: 0.0047
# Epoch 177: loss improved from 0.00004 to 0.00003, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 12s 4s/step - loss: 3.3835e-05 - mae: 0.0046
# Epoch 178/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - loss: 1
# Epoch 278/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 6.3665e-10 - mae: 1.2636e-05
# Epoch 278: loss improved from 0.00000 to 0.00000, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 8s 4s/step - loss: 5.8935e-10 - mae: 1.1921e-05
# Epoch 279/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 6.0209e-10 - mae: 1.2755e-05
# Epoch 279: loss did not improve from 0.00000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 6s 3s/step - loss: 5.9420e-10 - mae: 1.2557e-05
# Epoch 280/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 6.2573e-10 - mae: 1.3590e-05
# Epoch 280: loss did not improve from 0.00000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - loss: 6.7424e-10 - mae: 1.4305e-05
# Epoch 281/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - loss: 6.1118e-10 - mae: 1.3351e-05
# Epoch 281: loss did not improve from 0.00000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 7s 4s/step - loss: 5.9905e-10 - mae: 1.2875e-05
# Epoch 282/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 4.3656e-10 - mae: 8.8215e-06
# Epoch 282: loss did not improve from 0.00000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 9s 3s/step - loss: 4.8749e-10 - mae: 9.6957e-06
# Epoch 283/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 6.9849e-10 - mae: 1.4067e-05
# Epoch 283: loss did not improve from 0.00000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 7s 3s/step - loss: 7.4215e-10 - mae: 1.4941e-05
# Epoch 284/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - loss: 7.2760e-10 - mae: 1.4782e-05
# Epoch 284: loss did not improve from 0.00000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 11s 4s/step - loss: 6.9849e-10 - mae: 1.4305e-05
# Epoch 285/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 5.3296e-10 - mae: 1.0133e-05
# Epoch 285: loss improved from 0.00000 to 0.00000, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 7s 4s/step - loss: 5.0932e-10 - mae: 9.8546e-06
# Epoch 286/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 5.4024e-10 - mae: 1.0848e-05
# Epoch 286: loss did not improve from 0.00000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 7s 3s/step - loss: 5.3842e-10 - mae: 1.0808e-05
# Epoch 287/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - loss: 5.7662e-10 - mae: 1.1325e-05
# Epoch 287: loss did not improve from 0.00000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 4s/step - loss: 6.0148e-10 - mae: 1.1762e-05
# Epoch 288/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 4.3292e-10 - mae: 8.8215e-06
# Epoch 288: loss did not improve from 0.00000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 9s 3s/step - loss: 4.8264e-10 - mae: 9.6957e-06
# Epoch 289/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 4.6384e-10 - mae: 9.8944e-06
# Epoch 289: loss did not improve from 0.00000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - loss: 4.7294e-10 - mae: 1.0014e-05
# Epoch 290/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - loss: 6.9849e-10 - mae: 1.4067e-05
# Epoch 290: loss did not improve from 0.00000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 7s 4s/step - loss: 6.7181e-10 - mae: 1.3828e-05
# Epoch 291/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 4.2382e-10 - mae: 8.2254e-06
# Epoch 291: loss improved from 0.00000 to 0.00000, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 7s 4s/step - loss: 4.3413e-10 - mae: 8.4241e-06
# Epoch 292/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - loss: 5.2751e-10 - mae: 1.0967e-05
# Epoch 292: loss did not improve from 0.00000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 7s 4s/step - loss: 5.5782e-10 - mae: 1.1444e-05
# Epoch 293/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 6.2391e-10 - mae: 1.2040e-05
# Epoch 293: loss did not improve from 0.00000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 6s 3s/step - loss: 6.5241e-10 - mae: 1.2557e-05
# Epoch 294/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 8.4037e-10 - mae: 1.6928e-05
# Epoch 294: loss did not improve from 0.00000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - loss: 7.9065e-10 - mae: 1.5895e-05
# Epoch 295/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - loss: 8.8039e-10 - mae: 1.6689e-05
# Epoch 295: loss did not improve from 0.00000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 8s 4s/step - loss: 8.2703e-10 - mae: 1.5736e-05
# Epoch 296/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 5.2205e-10 - mae: 1.0371e-05
# Epoch 296: loss did not improve from 0.00000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 9s 3s/step - loss: 5.6995e-10 - mae: 1.1285e-05
# Epoch 297/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 5.0022e-10 - mae: 9.4175e-06
# Epoch 297: loss did not improve from 0.00000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - loss: 5.4327e-10 - mae: 1.0173e-05
# Epoch 298/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 6.2209e-10 - mae: 1.2159e-05
# Epoch 298: loss did not improve from 0.00000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - loss: 6.5726e-10 - mae: 1.2875e-05
# Epoch 299/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 4.4747e-10 - mae: 9.7752e-06
# Epoch 299: loss did not improve from 0.00000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 11s 3s/step - loss: 4.8021e-10 - mae: 1.0173e-05
# Epoch 300/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 7.2396e-10 - mae: 1.6451e-05
# Epoch 300: loss did not improve from 0.00000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 11s 3s/step - loss: 8.2218e-10 - mae: 1.7961e-05

# %%
import zipfile
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.image import load_img, img_to_array
import matplotlib.pyplot as plt
import math

test_zip_path = '/content/test.zip'
test_extract_path = '/content/'

with zipfile.ZipFile(test_zip_path, 'r') as zip_ref:
    zip_ref.extractall(test_extract_path)

print(f'File berhasil diekstrak ke {test_extract_path}')

image_dir = '/content/test'

images = []
labels = []

for filename in os.listdir(image_dir):
    if filename.endswith(".jpg"):
        img_path = os.path.join(image_dir, filename)
        img = load_img(img_path, target_size=(224, 224))
        img_array = img_to_array(img) / 255.0

        label = int(filename.split('.')[0])

        images.append(img_array)
        labels.append(label)

X = np.array(images)
y = np.array(labels)


best_model = tf.keras.models.load_model('best_model.keras')
prediksi_bobot = best_model.predict(X)
selisih = np.abs(y - prediksi_bobot.flatten())
persentase_kebenaran = 100 * (1 - selisih / y)
rata_rata_persentase = np.mean(persentase_kebenaran)


num_images = len(X)
cols = 5
rows = math.ceil(num_images / cols)

plt.figure(figsize=(cols * 3, rows * 3))

for i in range(num_images):
    plt.subplot(rows, cols, i + 1)
    plt.imshow(X[i])
    plt.axis('off')
    plt.title(f"Aktual: {y[i]} kg\nPrediksi: {prediksi_bobot[i][0]:.2f} kg\nSelisih: {selisih[i]:.2f} kg\nKebenaran: {persentase_kebenaran[i]:.2f}%", fontsize=8, color='black')

plt.suptitle(f"Rata-rata Persentase Kebenaran: {rata_rata_persentase:.2f}%", fontsize=12, y=1.02)
plt.tight_layout()
plt.show()
# Out:
# File berhasil diekstrak ke /content/
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 265ms/step

# %%
import zipfile
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.image import load_img, img_to_array
import matplotlib.pyplot as plt
import math
import cv2

# Ekstrak file ZIP test
test_zip_path = '/content/test.zip'
test_extract_path = '/content/'

with zipfile.ZipFile(test_zip_path, 'r') as zip_ref:
    zip_ref.extractall(test_extract_path)

print(f'File berhasil diekstrak ke {test_extract_path}')

# Load model segmentasi
segmentation_model = tf.keras.models.load_model('/content/segmentasi_model_unet_best.h5')

# Folder dataset
test_image_dir = '/content/test'
test_segmented_dir = '/content/test_segmented'
os.makedirs(test_segmented_dir, exist_ok=True)

SEGMENTATION_IMG_HEIGHT, SEGMENTATION_IMG_WIDTH = 256, 256
PREDICTION_IMG_HEIGHT, PREDICTION_IMG_WIDTH = 224, 224

def segment_image(image_path):
    image = cv2.imread(image_path)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    image = cv2.resize(image, (SEGMENTATION_IMG_WIDTH, SEGMENTATION_IMG_HEIGHT)) / 255.0
    image_input = np.expand_dims(image, axis=0)
    pred_mask = segmentation_model.predict(image_input)[0]
    pred_mask = (pred_mask > 0.5).astype(np.uint8)

    segmented_image = image * np.expand_dims(pred_mask[:, :, 0], axis=-1)
    return segmented_image

images = []
labels = []

for filename in os.listdir(test_image_dir):
    if filename.endswith(".jpg"):
        img_path = os.path.join(test_image_dir, filename)
        segmented_image = segment_image(img_path)
        segmented_path = os.path.join(test_segmented_dir, filename)
        cv2.imwrite(segmented_path, cv2.cvtColor((segmented_image * 255).astype(np.uint8), cv2.COLOR_RGB2BGR))

        img_array = img_to_array(load_img(segmented_path, target_size=(PREDICTION_IMG_HEIGHT, PREDICTION_IMG_WIDTH))) / 255.0
        label = int(filename.split('.')[0])

        images.append(img_array)
        labels.append(label)

X = np.array(images)
y = np.array(labels)

# Load model prediksi bobot sapi
best_model = tf.keras.models.load_model('best_model.keras')
prediksi_bobot = best_model.predict(X)
selisih = np.abs(y - prediksi_bobot.flatten())
persentase_kebenaran = 100 * (1 - selisih / y)
rata_rata_persentase = np.mean(persentase_kebenaran)

num_images = len(X)
cols = 5
rows = math.ceil(num_images / cols)

plt.figure(figsize=(cols * 3, rows * 3))

for i in range(num_images):
    plt.subplot(rows, cols, i + 1)
    plt.imshow(X[i])
    plt.axis('off')
    plt.title(f"Aktual: {y[i]} kg\nPrediksi: {prediksi_bobot[i][0]:.2f} kg\nSelisih: {selisih[i]:.2f} kg\nKebenaran: {persentase_kebenaran[i]:.2f}%", fontsize=8, color='black')

plt.suptitle(f"Rata-rata Persentase Kebenaran: {rata_rata_persentase:.2f}%", fontsize=12, y=1.02)
plt.tight_layout()
plt.show()
# Out:
# File berhasil diekstrak ke /content/
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step
